# %% [markdown]
# MICE stands for Multivariate Imputation by Chained Equations
#
# Assumtion for using MICE:
#     - Data should be Missing At Random (MAR)
#
# we get better results when we apply MICE at the data where we are sure that it is missing at random
