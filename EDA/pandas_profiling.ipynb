# %%
import pandas as pd

# %%
df = pd.read_csv('train.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
pip install ydata-profiling
# Out:
# Requirement already satisfied: ydata-profiling in /Users/pratyushtiwari/Desktop/Machine Learning CampusX/myvenv/lib/python3.11/site-packages (4.17.0)
# Requirement already satisfied: scipy<1.16,>=1.4.1 in /Users/pratyushtiwari/Desktop/Machine Learning CampusX/myvenv/lib/python3.11/site-packages (from ydata-profiling) (1.15.3)
# Requirement already satisfied: pandas!=1.4.0,<3.0,>1.1 in /Users/pratyushtiwari/Desktop/Machine Learning CampusX/myvenv/lib/python3.11/site-packages (from ydata-profiling) (2.3.2)
# Requirement already satisfied: matplotlib<=3.10,>=3.5 in /Users/pratyushtiwari/Desktop/Machine Learning CampusX/myvenv/lib/python3.11/site-packages (from ydata-profiling) (3.10.0)
# Collecting pydantic>=2 (from ydata-profiling)
#   Obtaining dependency information for pydantic>=2 from https://files.pythonhosted.org/packages/3e/d3/108f2006987c58e76691d5ae5d200dd3e0f532cb4e5fa3560751c3a1feba/pydantic-2.11.9-py3-none-any.whl.metadata
#   Using cached pydantic-2.11.9-py3-none-any.whl.metadata (68 kB)
# Requirement already satisfied: PyYAML<6.1,>=5.0.0 in /Users/pratyushtiwari/Desktop/Machine Learning CampusX/myvenv/lib/python3.11/site-packages (from ydata-profiling) (6.0.3)
# Requirement already satisfied: jinja2<3.2,>=2.11.1 in /Users/pratyushtiwari/Desktop/Machine Learning CampusX/myvenv/lib/python3.11/site-packages (from ydata-profiling) (3.1.6)
# Requirement already satisfied: visions[type_image_path]<0.8.2,>=0.7.5 in /Users/pratyushtiwari/Desktop/Machine Learning CampusX/myvenv/lib/python3.11/site-packages (from ydata-profiling) (0.8.1)
# Requirement already satisfied: numpy<2.2,>=1.16.0 in /Users/pratyushtiwari/Desktop/Machine Learning CampusX/myvenv/lib/python3.11/site-packages (from ydata-profiling) (1.26.4)
# Requirement already satisfied: minify-html>=0.15.0 in /Users/pratyushtiwari/Desktop/Machine Learning CampusX/myvenv/lib/python3.11/site-packages (from ydata-profiling) (0.16.4)
# Requirement already satisfied: filetype>=1.0.0 in /Users/pratyushtiwari/Desktop/Machine Learning CampusX/myvenv/lib/python3.11/site-packages (from ydata-profiling) (1.2.0)
# Requirement already satisfied: phik<0.13,>=0.11.1 in /Users/pratyushtiwari/Desktop/Machine Learning CampusX/myvenv/lib/python3.11/site-packages (from ydata-profiling) (0.12.5)
# Requirement already satisfied: requests<3,>=2.24.0 in /Users/pratyushtiwari/Desktop/Machine Learning CampusX/myvenv/lib/python3.11/site-packages (from ydata-profiling) (2.32.5)
# Requirement already satisfied: tqdm<5,>=4.48.2 in /Users/pratyushtiwari/Desktop/Machine Learning CampusX/myvenv/lib/python3.11/site-packages (from ydata-profiling) (4.67.1)
# Requirement already satisfied: seaborn<0.14,>=0.10.1 in /Users/pratyushtiwari/Desktop/Machine Learning CampusX/myvenv/lib/python3.11/site-packages (from ydata-profiling) (0.13.2)
# Requirement already satisfied: multimethod<2,>=1.4 in /Users/pratyushtiwari/Desktop/Machine Learning CampusX/myvenv/lib/python3.11/site-packages (from ydata-profiling) (1.12)
# Requirement already satisfied: statsmodels<1,>=0.13.2 in /Users/pratyushtiwari/Desktop/Machine Learning CampusX/myvenv/lib/python3.11/site-packages (from ydata-profiling) (0.14.5)
# Requirement already satisfied: typeguard<5,>=3 in /Users/pratyushtiwari/Desktop/Machine Learning CampusX/myvenv/lib/python3.11/site-packages (from ydata-profiling) (4.4.4)
# Requirement already satisfied: imagehash==4.3.1 in /Users/pratyushtiwari/Desktop/Machine Learning CampusX/myvenv/lib/python3.11/site-packages (from ydata-profiling) (4.3.1)
# Requirement already satisfied: wordcloud>=1.9.3 in /Users/pratyushtiwari/Desktop/Machine Learning CampusX/myvenv/lib/python3.11/site-packages (from ydata-profiling) (1.9.4)
# Requirement already satisfied: dacite>=1.8 in /Users/pratyushtiwari/Desktop/Machine Learning CampusX/myvenv/lib/python3.11/site-packages (from ydata-profiling) (1.9.2)
# Requirement already satisfied: numba<=0.61,>=0.56.0 in /Users/pratyushtiwari/Desktop/Machine Learning CampusX/myvenv/lib/python3.11/site-packages (from ydata-profiling) (0.61.0)
# Requirement already satisfied: PyWavelets in /Users/pratyushtiwari/Desktop/Machine Learning CampusX/myvenv/lib/python3.11/site-packages (from imagehash==4.3.1->ydata-profiling) (1.9.0)
# Requirement already satisfied: pillow in /Users/pratyushtiwari/Desktop/Machine Learning CampusX/myvenv/lib/python3.11/site-packages (from imagehash==4.3.1->ydata-profiling) (11.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/pratyushtiwari/Desktop/Machine Learning CampusX/myvenv/lib/python3.11/site-packages (from jinja2<3.2,>=2.11.1->ydata-profiling) (2.1.5)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/pratyushtiwari/Desktop/Machine Learning CampusX/myvenv/lib/python3.11/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/pratyushtiwari/Desktop/Machine Learning CampusX/myvenv/lib/python3.11/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/pratyushtiwari/Desktop/Machine Learning CampusX/myvenv/lib/python3.11/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (4.59.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/pratyushtiwari/Desktop/Machine Learning CampusX/myvenv/lib/python3.11/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /Users/pratyushtiwari/Desktop/Machine Learning CampusX/myvenv/lib/python3.11/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/pratyushtiwari/Desktop/Machine Learning CampusX/myvenv/lib/python3.11/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (3.2.4)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/pratyushtiwari/Desktop/Machine Learning CampusX/myvenv/lib/python3.11/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (2.9.0.post0)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in /Users/pratyushtiwari/Desktop/Machine Learning CampusX/myvenv/lib/python3.11/site-packages (from numba<=0.61,>=0.56.0->ydata-profiling) (0.44.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/pratyushtiwari/Desktop/Machine Learning CampusX/myvenv/lib/python3.11/site-packages (from pandas!=1.4.0,<3.0,>1.1->ydata-profiling) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/pratyushtiwari/Desktop/Machine Learning CampusX/myvenv/lib/python3.11/site-packages (from pandas!=1.4.0,<3.0,>1.1->ydata-profiling) (2025.2)
# Requirement already satisfied: joblib>=0.14.1 in /Users/pratyushtiwari/Desktop/Machine Learning CampusX/myvenv/lib/python3.11/site-packages (from phik<0.13,>=0.11.1->ydata-profiling) (1.1.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/pratyushtiwari/Desktop/Machine Learning CampusX/myvenv/lib/python3.11/site-packages (from pydantic>=2->ydata-profiling) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /Users/pratyushtiwari/Desktop/Machine Learning CampusX/myvenv/lib/python3.11/site-packages (from pydantic>=2->ydata-profiling) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /Users/pratyushtiwari/Desktop/Machine Learning CampusX/myvenv/lib/python3.11/site-packages (from pydantic>=2->ydata-profiling) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in /Users/pratyushtiwari/Desktop/Machine Learning CampusX/myvenv/lib/python3.11/site-packages (from pydantic>=2->ydata-profiling) (0.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/pratyushtiwari/Desktop/Machine Learning CampusX/myvenv/lib/python3.11/site-packages (from requests<3,>=2.24.0->ydata-profiling) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /Users/pratyushtiwari/Desktop/Machine Learning CampusX/myvenv/lib/python3.11/site-packages (from requests<3,>=2.24.0->ydata-profiling) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/pratyushtiwari/Desktop/Machine Learning CampusX/myvenv/lib/python3.11/site-packages (from requests<3,>=2.24.0->ydata-profiling) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/pratyushtiwari/Desktop/Machine Learning CampusX/myvenv/lib/python3.11/site-packages (from requests<3,>=2.24.0->ydata-profiling) (2025.8.3)
# Requirement already satisfied: patsy>=0.5.6 in /Users/pratyushtiwari/Desktop/Machine Learning CampusX/myvenv/lib/python3.11/site-packages (from statsmodels<1,>=0.13.2->ydata-profiling) (1.0.1)
# WARNING: visions 0.8.1 does not provide the extra 'type_image_path'
# Requirement already satisfied: attrs>=19.3.0 in /Users/pratyushtiwari/Desktop/Machine Learning CampusX/myvenv/lib/python3.11/site-packages (from visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (25.3.0)
# Requirement already satisfied: networkx>=2.4 in /Users/pratyushtiwari/Desktop/Machine Learning CampusX/myvenv/lib/python3.11/site-packages (from visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (3.5)
# Requirement already satisfied: puremagic in /Users/pratyushtiwari/Desktop/Machine Learning CampusX/myvenv/lib/python3.11/site-packages (from visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (1.30)
# Requirement already satisfied: six>=1.5 in /Users/pratyushtiwari/Desktop/Machine Learning CampusX/myvenv/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib<=3.10,>=3.5->ydata-profiling) (1.17.0)
# Using cached pydantic-2.11.9-py3-none-any.whl (444 kB)
# Installing collected packages: pydantic
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 1.10.24
#     Uninstalling pydantic-1.10.24:
#       Successfully uninstalled pydantic-1.10.24
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pandas-profiling 3.2.0 requires visions[type_image_path]==0.7.4, but you have visions 0.8.1 which is incompatible.
# Successfully installed pydantic-2.11.9
#
# [notice] A new release of pip is available: 23.2.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from pandas_profiling import ProfileReport
prof = ProfileReport(df)
prof.to_file(output_file="output.html")
# Out:
# 100%|██████████| 12/12 [00:00<00:00, 156.05it/s]<00:00, 79.57it/s, Describe variable: Embarked]
# Summarize dataset: 100%|██████████| 47/47 [00:01<00:00, 35.60it/s, Completed]
# Generate report structure: 100%|██████████| 1/1 [00:01<00:00,  1.64s/it]
# Render HTML: 100%|██████████| 1/1 [00:00<00:00,  7.46it/s]
# Export report to file: 100%|██████████| 1/1 [00:00<00:00, 234.62it/s]
